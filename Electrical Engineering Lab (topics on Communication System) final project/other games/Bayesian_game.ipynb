# %% [markdown]
# # Bayesian game circuit

# %%
# It is restricted to four strategies for each player
# It simply overlaps 8 combination of strategies (I)
import random
import qiskit
import numpy as np
from qiskit import QuantumCircuit , execute , Aer, QuantumRegister, ClassicalRegister
from qiskit.visualization import plot_histogram , plot_bloch_multivector
from math import sqrt , pi
r1 = 0

q=QuantumRegister(6)
c = ClassicalRegister(5)
circuit1 = QuantumCircuit(q,c)


circuit1.x(0)  #C = 1
circuit1.x(1)  #C = 1
circuit1.rx(-np.pi/2,0)
circuit1.rx(-np.pi/2,1)
circuit1.cx(q[0],q[2])
circuit1.cx(q[1],q[2])
circuit1.rz(r1,q[2])
circuit1.cx(q[1],q[2])
circuit1.cx(q[0],q[2])
circuit1.rx(np.pi/2,1)
circuit1.rx(np.pi/2,0)

circuit1.h(3)
circuit1.h(4)
circuit1.h(5)
circuit1.cx(q[3],q[0])
circuit1.cz(q[4],q[0])
circuit1.cz(q[5],q[1]) 

circuit1.rx(-np.pi/2,0)
circuit1.rx(-np.pi/2,1)
circuit1.cx(q[0],q[2])
circuit1.cx(q[1],q[2])
circuit1.rz(-r1,q[2])
circuit1.cx(q[1],q[2])
circuit1.cx(q[0],q[2])
circuit1.rx(np.pi/2,1)
circuit1.rx(np.pi/2,0)
circuit1.measure([0,1,3,4,5],[0,1,2,3,4])
circuit1.draw()
# Out:
#       ┌───┐┌───────────┐                             ┌──────────┐   ┌───┐»
# q0_0: ┤ X ├┤ RX(-pi/2) ├──■───────────────────────■──┤ RX(pi/2) ├───┤ X ├»
#       ├───┤├───────────┤  │                       │  ├──────────┤   └─┬─┘»
# q0_1: ┤ X ├┤ RX(-pi/2) ├──┼────■─────────────■────┼──┤ RX(pi/2) ├─■───┼──»
#       └───┘└───────────┘┌─┴─┐┌─┴─┐┌───────┐┌─┴─┐┌─┴─┐└──────────┘ │   │  »
# q0_2: ──────────────────┤ X ├┤ X ├┤ RZ(0) ├┤ X ├┤ X ├─────────────┼───┼──»
#       ┌───┐             └───┘└───┘└───────┘└───┘└───┘             │   │  »
# q0_3: ┤ H ├───────────────────────────────────────────────────────┼───■──»
#       ├───┤                                                       │      »
# q0_4: ┤ H ├───────────────────────────────────────────────────────┼──────»
#       ├───┤                                                       │  ┌─┐ »
# q0_5: ┤ H ├───────────────────────────────────────────────────────■──┤M├─»
# ...

# %%
# It is restricted to four strategies for each player
# It simply overlaps 8 combination of strategies (X)
import random
import qiskit
import numpy as np
from qiskit import QuantumCircuit , execute , Aer, QuantumRegister, ClassicalRegister
from qiskit.visualization import plot_histogram , plot_bloch_multivector
from math import sqrt , pi
r1 = 0
p=0.5
q=QuantumRegister(6)
c = ClassicalRegister(5)
circuit1 = QuantumCircuit(q,c)


circuit1.x(0)  #C = 1
circuit1.x(1)  #C = 1
circuit1.rx(-np.pi/2,0)
circuit1.rx(-np.pi/2,1)
circuit1.cx(q[0],q[2])
circuit1.cx(q[1],q[2])
circuit1.rz(r1,q[2])
circuit1.cx(q[1],q[2])
circuit1.cx(q[0],q[2])
circuit1.rx(np.pi/2,1)
circuit1.rx(np.pi/2,0)

circuit1.h(3)
circuit1.h(4)
circuit1.h(5)
circuit1.cx(q[3],q[0])
circuit1.cz(q[4],q[0])
circuit1.cz(q[5],q[1])
circuit1.x(1) 
circuit1.rx(-np.pi/2,0)
circuit1.rx(-np.pi/2,1)
circuit1.cx(q[0],q[2])
circuit1.cx(q[1],q[2])
circuit1.rz(-r1,q[2])
circuit1.cx(q[1],q[2])
circuit1.cx(q[0],q[2])
circuit1.rx(np.pi/2,1)
circuit1.rx(np.pi/2,0)
circuit1.measure([0,1,3,4,5],[0,1,2,3,4])
circuit1.draw()
# Out:
#       ┌───┐┌───────────┐                             ┌──────────┐   ┌───┐     »
# q1_0: ┤ X ├┤ RX(-pi/2) ├──■───────────────────────■──┤ RX(pi/2) ├───┤ X ├─────»
#       ├───┤├───────────┤  │                       │  ├──────────┤   └─┬─┘┌───┐»
# q1_1: ┤ X ├┤ RX(-pi/2) ├──┼────■─────────────■────┼──┤ RX(pi/2) ├─■───┼──┤ X ├»
#       └───┘└───────────┘┌─┴─┐┌─┴─┐┌───────┐┌─┴─┐┌─┴─┐└──────────┘ │   │  └───┘»
# q1_2: ──────────────────┤ X ├┤ X ├┤ RZ(0) ├┤ X ├┤ X ├─────────────┼───┼───────»
#       ┌───┐             └───┘└───┘└───────┘└───┘└───┘             │   │   ┌─┐ »
# q1_3: ┤ H ├───────────────────────────────────────────────────────┼───■───┤M├─»
#       ├───┤                                                       │       └╥┘ »
# q1_4: ┤ H ├───────────────────────────────────────────────────────┼────────╫──»
#       ├───┤                                                       │  ┌─┐   ║  »
# q1_5: ┤ H ├───────────────────────────────────────────────────────■──┤M├───╫──»
# ...

# %% [markdown]
# # Find Nash Euilibrium

# %%
import random
import qiskit
import numpy as np
from qiskit import QuantumCircuit , execute , Aer, QuantumRegister, ClassicalRegister
from qiskit.visualization import plot_histogram , plot_bloch_multivector
from math import sqrt , pi
r1 = 0

q=QuantumRegister(6)
c = ClassicalRegister(5)
circuit1 = QuantumCircuit(q,c)

circuit1.x(0)  #C = 1
circuit1.x(1)  #C = 1
circuit1.rx(-np.pi/2,0)
circuit1.rx(-np.pi/2,1)
circuit1.cx(q[0],q[2])
circuit1.cx(q[1],q[2])
circuit1.rz(r1,q[2])
circuit1.cx(q[1],q[2])
circuit1.cx(q[0],q[2])
circuit1.rx(np.pi/2,1)
circuit1.rx(np.pi/2,0)

circuit1.h(3)
circuit1.h(4)
circuit1.h(5)
circuit1.cx(q[3],q[0])
circuit1.cz(q[4],q[0])
circuit1.cz(q[5],q[1]) 

circuit1.rx(-np.pi/2,0)
circuit1.rx(-np.pi/2,1)
circuit1.cx(q[0],q[2])
circuit1.cx(q[1],q[2])
circuit1.rz(-r1,q[2])
circuit1.cx(q[1],q[2])
circuit1.cx(q[0],q[2])
circuit1.rx(np.pi/2,1)
circuit1.rx(np.pi/2,0)
circuit1.measure([0,1,3,4,5],[0,1,2,3,4])
circuit1.draw()
backend = Aer.get_backend('qasm_simulator')
shots = 1024
results = execute(circuit1, backend=backend, shots=shots).result()
answer = results.get_counts()
payoff_matrix1=np.array(
        [[11,9],[1,10],[10,1],[6,6]]
            )
payoff_matrix2=np.array(
        [[11,9],[1,6],[10,1],[6,0]]
            )
times=[0,0,0,0,0,0,0,0]
for l in answer:
        num=int(l[0])*4+int(l[1])*2+int(l[2])
        times[num]=times[num]+answer[l]
    
payoff1=[0,0,0,0,0,0,0,0]

for k in answer:
        num=int(k[0])*4+int(k[1])*2+int(k[2])
        if (k[3:5]=="11"):
            payoff1[num]=payoff1[num]+payoff_matrix1[0]*answer[k]/times[num]

        if (k[3:5]=="10"):
            payoff1[num]=payoff1[num]+payoff_matrix1[2]*answer[k]/times[num]

        if (k[3:5]=="01"):
            payoff1[num]=payoff1[num]+payoff_matrix1[1]*answer[k]/times[num]

        if (k[3:5]=="00"):
            payoff1[num]=payoff1[num]+payoff_matrix1[3]*answer[k]/times[num]
payoff2=[0,0,0,0,0,0,0,0]

for k in answer:
        num=int(k[0])*4+int(k[1])*2+int(k[2])
        if (k[3:5]=="11"):
            payoff2[num]=payoff2[num]+payoff_matrix2[0]*answer[k]/times[num]

        if (k[3:5]=="10"):
            payoff2[num]=payoff2[num]+payoff_matrix2[2]*answer[k]/times[num]

        if (k[3:5]=="01"):
            payoff2[num]=payoff2[num]+payoff_matrix2[1]*answer[k]/times[num]

        if (k[3:5]=="00"):
            payoff2[num]=payoff2[num]+payoff_matrix2[3]*answer[k]/times[num]   
total_payoff=[0,0,0,0,0,0,0,0]
for i in range(len(payoff1)):
    total_payoff[i]=p*payoff1[i]+(1-p)*payoff2[i]
import random
import qiskit
import numpy as np
from qiskit import QuantumCircuit , execute , Aer, QuantumRegister, ClassicalRegister
from qiskit.visualization import plot_histogram , plot_bloch_multivector
from math import sqrt , pi
r1 = 0
p=0.5
q=QuantumRegister(6)
c = ClassicalRegister(5)
circuit1 = QuantumCircuit(q,c)


circuit1.x(0)  #C = 1
circuit1.x(1)  #C = 1
circuit1.rx(-np.pi/2,0)
circuit1.rx(-np.pi/2,1)
circuit1.cx(q[0],q[2])
circuit1.cx(q[1],q[2])
circuit1.rz(r1,q[2])
circuit1.cx(q[1],q[2])
circuit1.cx(q[0],q[2])
circuit1.rx(np.pi/2,1)
circuit1.rx(np.pi/2,0)

circuit1.h(3)
circuit1.h(4)
circuit1.h(5)
circuit1.cx(q[3],q[0])
circuit1.cz(q[4],q[0])
circuit1.cz(q[5],q[1])
circuit1.x(1) 
circuit1.rx(-np.pi/2,0)
circuit1.rx(-np.pi/2,1)
circuit1.cx(q[0],q[2])
circuit1.cx(q[1],q[2])
circuit1.rz(-r1,q[2])
circuit1.cx(q[1],q[2])
circuit1.cx(q[0],q[2])
circuit1.rx(np.pi/2,1)
circuit1.rx(np.pi/2,0)
circuit1.measure([0,1,3,4,5],[0,1,2,3,4])
circuit1.draw()
backend = Aer.get_backend('qasm_simulator')
shots = 1024*16
results = execute(circuit1, backend=backend, shots=shots).result()
answer = results.get_counts()
payoff_matrix1=np.array(
        [[11,9],[1,10],[10,1],[6,6]]
            )
payoff_matrix2=np.array(
        [[11,9],[1,6],[10,1],[6,0]]
            )
times=[0,0,0,0,0,0,0,0]
for l in answer:
        num=int(l[0])*4+int(l[1])*2+int(l[2])
        times[num]=times[num]+answer[l]
    
payoff1=[0,0,0,0,0,0,0,0]

for k in answer:
        num=int(k[0])*4+int(k[1])*2+int(k[2])
        if (k[3:5]=="11"):
            payoff1[num]=payoff1[num]+payoff_matrix1[0]*answer[k]/times[num]

        if (k[3:5]=="10"):
            payoff1[num]=payoff1[num]+payoff_matrix1[2]*answer[k]/times[num]

        if (k[3:5]=="01"):
            payoff1[num]=payoff1[num]+payoff_matrix1[1]*answer[k]/times[num]

        if (k[3:5]=="00"):
            payoff1[num]=payoff1[num]+payoff_matrix1[3]*answer[k]/times[num]
payoff2=[0,0,0,0,0,0,0,0]

for k in answer:
        num=int(k[0])*4+int(k[1])*2+int(k[2])
        if (k[3:5]=="11"):
            payoff2[num]=payoff2[num]+payoff_matrix2[0]*answer[k]/times[num]

        if (k[3:5]=="10"):
            payoff2[num]=payoff2[num]+payoff_matrix2[2]*answer[k]/times[num]

        if (k[3:5]=="01"):
            payoff2[num]=payoff2[num]+payoff_matrix2[1]*answer[k]/times[num]

        if (k[3:5]=="00"):
            payoff2[num]=payoff2[num]+payoff_matrix2[3]*answer[k]/times[num]   
total_payoff2=[0,0,0,0,0,0,0,0]
for i in range(len(payoff1)):
    total_payoff2[i]=p*payoff1[i]+(1-p)*payoff2[i]

# %%
print("Below is payoff matrix with four strategies")
print(total_payoff[0],total_payoff[1],total_payoff[2],total_payoff[3])
print(total_payoff[4],total_payoff[5],total_payoff[6],total_payoff[7])
print(total_payoff2[0],total_payoff2[1],total_payoff2[2],total_payoff2[3])
print(total_payoff2[4],total_payoff2[5],total_payoff2[6],total_payoff2[7])
print(" ")
print(total_payoff[0],"is Nash Equilibrium without entanglement")
# Out:
# Below is payoff matrix with four strategies
# [11.  9.] [10.  1.] [11.  9.] [10.  1.]
# [11.  9.] [10.  1.] [11.  9.] [10.  1.]
# [1. 8.] [6. 3.] [1. 8.] [6. 3.]
# [1. 8.] [6. 3.] [1. 8.] [6. 3.]
#
# [11.  9.] is Nash Equilibrium without entanglement
